# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from sklearn.model_selection import train_test_split
import sys
import time
from matplotlib import pyplot as plt
import keras
import pandas as pd
from pandas import DataFrame as df
import ast
from skimage.transform import resize

def convert(data, genres):
    out = [0]* len(genres)
    data = str(data)
    data = data.replace('[', '')
    data = data.replace(']', '')
    data = data.replace('\'', '')
    data = data.split(',')
    for i in data:
        out[genres.index(i)] = 1
        break
    return out
def convertx(data):
    data = data.replace('...', '')
    data = ast.literal_eval(data)
    return data

def load_csv(file_dir,genres):
    data = pd.read_csv(file_dir)
    x = data['poster']
    y = data['genre']
#     x = x.apply(convertx)
    y = y.apply(convert, args=(genres,))
    return data,x,y

file_dir = "image_data.csv"
genres =['Animation', 'Comedy', 'Family', 'Adventure', 'Fantasy', 'Romance', 'Drama', 'Action', 'Crime', 'Thriller', 'Horror', 'History', 'Science Fiction', 'Mystery', 'War', 'Foreign', 'Music', 'Documentary', 'Western', 'TV Movie']

data,x,y = load_csv(file_dir,genres)

print(x.iloc[1])
print(y.head(5))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-df4d79639331> in <module>
#      12 from pandas import DataFrame as df
#      13 import ast
# ---> 14 from skimage.transform import resize
#      15
#      16 def convert(data, genres):
#
# ~\Anaconda3\lib\site-packages\skimage\__init__.py in <module>
#     174                              dtype_limits)
#     175
# --> 176     from .util.lookfor import lookfor
#     177     from .data import data_dir
#     178
#
# ~\Anaconda3\lib\site-packages\skimage\util\__init__.py in <module>
#       6 from .apply_parallel import apply_parallel
#       7
# ----> 8 from .arraycrop import crop
#       9 from ._regular_grid import regular_grid, regular_seeds
#      10 from .unique import unique_rows
#
# ~\Anaconda3\lib\site-packages\skimage\util\arraycrop.py in <module>
#       6
#       7 import numpy as np
# ----> 8 from numpy.lib.arraypad import _validate_lengths
#       9
#      10
#
# ImportError: cannot import name '_validate_lengths' from 'numpy.lib.arraypad' (C:\Users\Chan Ho Park\Anaconda3\lib\site-packages\numpy\lib\arraypad.py)

# %%
for index, row in data.iterrows():

    if len(row[3]) >= 3 and type(row[11]) is str:
        genre = []
        for elem in ast.literal_eval(row[3]):
            genre.append(elem['name'])
        poster_path = "http://image.tmdb.org/t/p/w185" + row[11] 
        
        try:
            image = io.imread(poster_path)
        except:
            print("An exception occurred")
            continue

        image_resized = resize(image, (278, 185))
        row = pd.DataFrame({"genre":[genre],
                            "poster": [image_resized]})    
        image_data = genre_data.append(row, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-8d2ed17c0018> in <module>
#       1 image_data = pd.DataFrame(columns = ["genre", "poster"])
#       2
# ----> 3 for index, row in df.iterrows():
#       4
#       5     if len(row[3]) >= 3 and type(row[11]) is str:
#
# TypeError: iterrows() missing 1 required positional argument: 'self'

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,random_state=100,stratify=y,test_size=.15)
train_datagen = ImageDataGenerator(
	        rescale=1./255,
	        horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow(X_train,y_train)
test_generator = test_datagen.flow(X_test,y_test)

# dimensions of images.
img_height,img_width = X_train.shape[1],X_train.shape[2]

# number of class
num_class = y_train.shape[1]

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_height, img_width)
else:
    input_shape = (img_height, img_width, 3)
print 'input shape: ',input_shape
# layer 1
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# layer 2
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# layer 3
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# layer 4
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
# layer 5
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
# layer 6
model.add(Dense(32))
model.add(Activation('relu'))
model.add(Dropout(0.5))
# layer 7
model.add(Dense(num_class))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

batch_size = 32

hist = model.fit_generator(
    train_generator,
    steps_per_epoch=len(X_train) / 32,
      epochs=epochs,
    validation_data=test_generator,
  #   callbacks=[callback],
    validation_steps = len(X_test)/32)
model.save(save)
